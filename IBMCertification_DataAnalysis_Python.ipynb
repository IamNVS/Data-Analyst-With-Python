# %%
import pandas as pd

url = "Rotten_Tomatoes_Movies3.csv"
df = pd.read_csv(url)

df.head(5)

df.tail(5)
# Out:
#            movie_title                                         movie_info  \
# 16633        Zoot Suit  Based on a 1940s Los Angeles murder trial, thi...
# 16634         Zootopia  The modern mammal metropolis of Zootopia is a ...
# 16635  Zorba the Greek  If ever there was a role that Anthony Quinn wa...
# 16636             Zulu  Filmed on a grand scale, Zulu is a rousing rec...
# 16637        Zulu Dawn  A prequel to Zulu, Zulu Dawn depicts the event...
#
#                                        critics_consensus rating  \
# 16633                                                NaN      R
# 16634  The brilliantly well-rounded Zootopia offers a...     PG
# 16635                                                NaN     NR
# 16636                                                NaN     PG
# 16637                                                NaN     PG
#
#                                                    genre  \
# 16633                   Drama, Musical & Performing Arts
# ...

# %%
import pandas as pd
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath)

url = "Rotten_Tomatoes_Movies3.csv"
df = pd.read_csv(url)
df.dtypes
df.describe()
df.describe(include='all')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16638 entries, 0 to 16637
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movie_title         16638 non-null  object
#  1   movie_info          16614 non-null  object
#  2   critics_consensus   8309 non-null   object
#  3   rating              16638 non-null  object
#  4   genre               16621 non-null  object
#  5   directors           16524 non-null  object
#  6   writers             15289 non-null  object
#  7   cast                16354 non-null  object
#  8   in_theaters_date    15823 non-null  object
#  9   on_streaming_date   16636 non-null  object
#  10  runtime_in_minutes  16483 non-null  float64
#  11  studio_name         16222 non-null  object
#  12  tomatometer_status  16638 non-null  object
#  13  tomatometer_rating  16638 non-null  int64
#  14  tomatometer_count   16638 non-null  int64
# ...

# %%
# MISSING VALUE

import pandas as pd
import numpy as np
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
# This is to replace ? to NAN in table database 
df = pd.read_csv(filepath , na_values = '?')
df.head(10)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

df.columns= headers
df.head(10)
# df.to_csv('example.csv')
df[['symboling','horsepower']].describe()
df.describe(include='all')

df.head()
df.dtypes

# df["normalized-losses"] = pd.to_numeric(df['normalized-losses'])
# df = df.replace('?',np.nan)
# df.dtypes

# This is to replace the NAN value to mean of the column 
mean=df['normalized-losses'].mean()
print(mean)
df['normalized-losses'].fillna(value=mean, inplace=True)
df.head(100)
# Out:
# 122.0
# C:\Users\Niraj Shegokar Panda\AppData\Local\Temp\ipykernel_6712\2368968159.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['normalized-losses'].fillna(value=mean, inplace=True)
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3              122.0  alfa-romero       gas        std
# 1           1              122.0  alfa-romero       gas        std
# 2           2              164.0         audi       gas        std
# ...

# %%
# MISSING VALUE

import pandas as pd
import numpy as np
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

df.head(25)
# This line drop NAN row in the table axis=0 to drop row and axis =1 is to drop column 
# df.dropna(subset=['normalized-losses'], axis=0,inplace=True)
df.head(25)
df.dtypes
df.head(25)
df.dtypes
df['city-mpg']
# Out:
# 0      21
# 1      19
# 2      24
# 3      18
# 4      19
#        ..
# 199    23
# 200    19
# 201    18
# 202    26
# 203    19
# Name: city-mpg, Length: 204, dtype: int64

# %%
# DATA FORMATTING

import pandas as pd
import numpy as np
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers


# This is to convert into mpg into liter per km
df['city-mpg']  = 235/df['city-mpg'] 
df.rename(columns = {'city-mpg' : 'city-kml' }, inplace=True)
df.dtypes
# This is to convert data type 
df['city-kml'].astype(int)
# Out:
# 0      11
# 1      12
# 2       9
# 3      13
# 4      12
#        ..
# 199    10
# 200    12
# 201    13
# 202     9
# 203    12
# Name: city-kml, Length: 204, dtype: int64

# %%
# DATA NORMALIZATION

import pandas as pd
import numpy as np
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

df.head(10)
# This is z-score method
df["price"] = (df["price"]-df["price"].mean())/ df["price"].std()

# This is min max method
# df["price"] = (df["price"]-df["price"].min()) / (df["price"].max-df["price"].min())

# This is simple feature scaling method
# df["price"] = df["price"]/ df["price"].max()

df["price"]
# Out:
# 0      0.413495
# 1      0.413495
# 2      0.093424
# 3      0.532737
# 4      0.256598
#          ...
# 199    0.456799
# 200    0.732939
# 201    1.039203
# 202    1.162838
# 203    1.182293
# Name: price, Length: 204, dtype: float64

# %%
# BINNING 

import pandas as pd
import numpy as np
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

df.head(10)
bin = np.linspace(min(df["price"]),max(df["price"]),4)
# print(bin)
group_name = ["Low" ,"Medium", "High"]

df["price_binned"] = pd.cut(df["price"],bin,labels=group_name,include_lowest=True)
df["price_binned"]
# Out:
# 0         Low
# 1         Low
# 2         Low
# 3         Low
# 4         Low
#         ...
# 199       Low
# 200    Medium
# 201    Medium
# 202    Medium
# 203    Medium
# Name: price_binned, Length: 204, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
import pandas as pd
import numpy as np
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers
df.head(10)
df.dtypes
df["fuel-type"]
fuel_dummie = pd.get_dummies(df["fuel-type"])
# This is to add two new columns in the data deisel, gas a delete the orignal column
df = pd.concat([df, fuel_dummie], axis=1)
df.drop("fuel-type",axis=1)
df.dtypes
# This is to get all null values in table
missing  = df.isnull()
# missing.head(10)

for column in missing.columns.values.tolist():
    print(column)
    print(missing[column].value_counts())
    print("")

# missing.value_counts().idxmax()
# Out:
# symboling
# symboling
# False    204
# Name: count, dtype: int64
#
# normalized-losses
# normalized-losses
# False    164
# True      40
# Name: count, dtype: int64
#
# make
# make
# False    204
# Name: count, dtype: int64
#
# fuel-type
# fuel-type
# False    204
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    204
# Name: count, dtype: int64
#
# num-of-doors
# num-of-doors
# False    202
# True       2
# Name: count, dtype: int64
#
# body-style
# body-style
# False    204
# Name: count, dtype: int64
#
# drive-wheels
# drive-wheels
# False    204
# Name: count, dtype: int64
#
# engine-location
# engine-location
# False    204
# Name: count, dtype: int64
#
# wheel-base
# wheel-base
# False    204
# Name: count, dtype: int64
#
# length
# length
# False    204
# Name: count, dtype: int64
#
# width
# width
# False    204
# Name: count, dtype: int64
#
# height
# height
# False    204
# Name: count, dtype: int64
#
# curb-weight
# curb-weight
# False    204
# ...

# %%
import pandas as pd
import numpy as np
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers
df.head(10)
drive_wheels_count = df['drive-wheels'].value_counts()
drive_wheels_count.head(10)
# Out:
# drive-wheels
# fwd    120
# rwd     75
# 4wd      9
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers
df.head(10)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          1                NaN  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2                NaN         audi       gas        std
# 5          1              158.0         audi       gas        std
# 6          1                NaN         audi       gas        std
# 7          1              158.0         audi       gas      turbo
# 8          0                NaN         audi       gas      turbo
# 9          2              192.0          bmw       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers
df.head(10)
sns.boxplot(x = "drive-wheels", y ="price",data = df )
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

x = df["engine-size"]
y = df["price"]
plt.scatter(x,y)
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.title("Scatter plot of engine vs price")
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers
# means= df["price"].mean()

# This is to group by the value in new table 

# converting non-numeric data to NaN or filtering it out 
df["price"] = pd.to_numeric(df["price"], errors="coerce")
# Grouping By the value
# This is to new table and mean of value numeric_only=True is for numeric value mean 
df_grp = df.groupby(["drive-wheels","body-style"], as_index=False)["price"].mean(numeric_only=True)
# print(df_grp)
df_pivot = df_grp.pivot(index = "drive-wheels", columns ='body-style')
# print(df_pivot)
plt.pcolor(df_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
pip install scipy
# Out:
# ...
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers
# This is show ANOVA of two types
df["price"] = pd.to_numeric(df["price"], errors="coerce")
df_group = df.groupby('make')['price']
honda_prices = df_group.get_group('honda')
jaguar_price = df_group.get_group('jaguar')
subaru_prices = df_group.get_group('subaru')
results = sc.f_oneway(honda_prices,jaguar_price)
results2 = sc.f_oneway(honda_prices,subaru_prices)
print(results2)
print(results)
# Out:
# F_onewayResult(statistic=np.float64(0.19744030127462606), pvalue=np.float64(0.6609478240622193))
# F_onewayResult(statistic=np.float64(400.925870564337), pvalue=np.float64(1.0586193512077865e-11))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers
# This is for Postive Linear
sns.regplot(x= "engine-size" , y = "price", data = df)

# This is for Negtive Linear
sns.regplot(x= "highway-mpg" , y = "price", data = df)

# This is for weak corelation
sns.regplot(x= "peak-rpm" , y = "price", data = df)


plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
# This is to Correlation of two Statics

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers
df["horsepower"] = pd.to_numeric(df["horsepower"], errors="coerce")
df["price"] = pd.to_numeric(df["price"], errors="coerce")
df_cleaned = df.dropna(subset=["horsepower", "price"])

persons_coefficent, p_value = sc.pearsonr(df_cleaned["horsepower"],df_cleaned["price"])
print("Persona Coefficent:-",persons_coefficent)
print("P_Value:-",p_value)
# Out:
# Persona Coefficent:- 0.8105870539462103
# P_Value:- 1.9850422817671387e-47

# %%
# This is linear regassion model

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lm = LinearRegression()

x= df["km_liter"].values.reshape(-1,1)
y= df["price"]

lm.fit(x,y)
result = lm.predict(x)
# print(result)
# If you want to see them alongside actual values:
df["predicted_price"] = result
print(df[["km_liter", "price", "predicted_price"]].head(10))

# You can predict the price for a specific km_liter value:
new_data = np.array([[32]])  
predicted_price = lm.predict(new_data)
print(f"Predicted price for 12 km/l: ${predicted_price}")

# Visualize Predictions vs. Actual Prices
plt.figure(figsize=(8,6))
sns.scatterplot(x=df["km_liter"], y=df["price"], label="Actual Price", color="blue")
sns.lineplot(x=df["km_liter"], y=result, label="Predicted Price", color="red")
plt.xlabel("Fuel Efficiency (km per liter)")
plt.ylabel("Car Price ($)")
plt.title("Actual vs Predicted Car Prices")
plt.legend()
plt.show()

# Check how well your model performs using R² Score:
r2 = r2_score(y, result)
print(f"R² Score: {r2:.2f}")  # Closer to 1 means better fit
# Out:
#      km_liter    price  predicted_price
# 0    8.703704  16500.0     15496.768269
# 1    9.038462  16500.0     16655.241611
# 2    7.833333  13950.0     12484.737582
# 3   10.681818  17450.0     22342.292559
# 4    9.400000  15250.0     17906.392819
# 5    9.400000  17710.0     17906.392819
# 6    9.400000  18920.0     17906.392819
# 7   11.750000  23875.0     26038.875675
# 9    8.103448  16430.0     13419.505726
# 10   8.103448  16925.0     13419.505726
# Predicted price for 12 km/l: $[96116.65347886]
# R² Score: 0.64

# %%
# This is multiple linear regression method

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lm = LinearRegression()

z = df[["km_liter","engine-size","horsepower","curb-weight"]].values
y = df["price"].values
lm.fit(z,y)

result = lm.predict(z)
# print(result)
# If you want to see them alongside actual values:
df["predicted_price"] = result
print(df[["km_liter","engine-size","horsepower","curb-weight", "price", "predicted_price"]].head(10))

# You can predict the price for a specific km_liter value:
new_data = np.array([[32,3212,30,123]])  
predicted_price = lm.predict(new_data)
print(f"Predicted price for 12 km/l: ${predicted_price}")

# Visualize Predictions vs. Actual Prices
plt.figure(figsize=(8,6))
sns.scatterplot(x=df["km_liter"], y=df["price"], label="Actual Price", color="blue")
sns.lineplot(x=df["km_liter"], y=result, label="Predicted Price", color="red")
plt.xlabel("Fuel Efficiency (km per liter)")
plt.ylabel("Car Price ($)")
plt.title("Actual vs Predicted Car Prices")
plt.legend()
plt.show()

# Check how well your model performs using R² Score:
r2 = r2_score(y, result)
print(f"R² Score: {r2:.2f}")  # Closer to 1 means better fit
# Out:
#      km_liter  engine-size  horsepower  curb-weight    price  predicted_price
# 0    8.703704          130       111.0         2548  16500.0     14086.600270
# 1    9.038462          152       154.0         2823  16500.0     18692.612703
# 2    7.833333          109       102.0         2337  13950.0     10792.900551
# 3   10.681818          136       115.0         2824  17450.0     16664.267965
# 4    9.400000          136       110.0         2507  15250.0     14755.830404
# 5    9.400000          136       110.0         2844  17710.0     15934.305752
# 6    9.400000          136       110.0         2954  18920.0     16318.971296
# 7   11.750000          131       140.0         3086  23875.0     18588.967226
# 9    8.103448          108       101.0         2395  16430.0     11002.259957
# 10   8.103448          108       101.0         2395  16925.0     11002.259957
# Predicted price for 12 km/l: $[278695.45508957]
# R² Score: 0.81

# %%
# This is to plot single linear rigression 

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lm = LinearRegression()

z = df["km_liter"].values.reshape(-1,1)
y = df["price"].values
lm.fit(z,y)

result = lm.predict(z)
# This is for regression plot
sns.regplot(x = 'km_liter' , y = 'price' , data=df)
plt.ylim(0,)

# This is for residual plot
sns.residplot(x=df["km_liter"].values.reshape(-1,1),y=df["price"].values.reshape(-1,1))
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lm = LinearRegression()

z = df[["km_liter","engine-size","horsepower","curb-weight"]].values
y = df["price"].values
lm.fit(z,y)

result = lm.predict(z)
ax1 = sns.displot(df['price'] , color="r", label='Actual Value')
sns.displot(result, color='b',label='Fitted Value' , ax =ax1 )
# Out:
# C:\Users\Niraj Shegokar Panda\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
# This is for polynomial regression model for single
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lm = LinearRegression()

x= df["km_liter"].values.reshape(-1,1)
y= df["price"]

degree = 3
poly = PolynomialFeatures(degree=degree)
X_poly = poly.fit_transform(x)

lm.fit(X_poly, y)
y_pred = lm.predict(X_poly)

r2 = r2_score(y, y_pred)
print(f"R² Score: {r2:.2f}") 

# f = np.polyfit(x,y,3)
# p = np.poly2d

# print(p)
# lm.fit(x,y)
# result = lm.predict(x)
plt.figure(figsize=(8,6))
sns.scatterplot(x=df["km_liter"], y=df["price"], label="Actual Price", color="blue")
sns.lineplot(x=df["km_liter"], y=y_pred, label="Polynomial Fit", color="red")
plt.xlabel("Fuel Efficiency (km per liter)")
plt.ylabel("Car Price ($)")
plt.title("Polynomial Regression: Car Price vs Fuel Efficiency")
plt.legend()
plt.show()
# Out:
# R² Score: 0.68

# %%
# This is for polynomial regression model for single

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lm = LinearRegression()

z = df[["km_liter","engine-size","horsepower","curb-weight"]].values
y = df["price"].astype(float).values

# pr = PolynomialFeatures(degree=2, include_bias=False)

# This is by using StandardScaler 
# Scaler  = StandardScaler()
# Scaler.fit(df[["km_liter","engine-size","horsepower","curb-weight"]].values)
# x_scaler = Scaler.transform(df[["km_liter","engine-size","horsepower","curb-weight"]].values)
# print(x_scaler)

Input = [('scaler',StandardScaler()), ('polynomial',PolynomialFeatures(degree=2)), ('model', LinearRegression())]
pipe = Pipeline(Input)
# pipe.train(z["km_liter","engine-size","horsepower","curb-weight"], y)
pipe.fit(z, y)
result = pipe.predict(z)
# print(result)

# Predict Price for a New Car
new_car = np.array([[15, 2000, 15, 25000]])  # Example input: 15 km/l, 2000cc, 150 HP, 2500 kg
predicted_price = pipe.predict(new_car)
print(f"Predicted Price: ${predicted_price[0]:.2f}")

# Evaluate Model Performance in r2 method
r2 = r2_score(y, result)
print(f"R² Score: {r2:.2f}")

# Evaluate Model Performance in mean squre method
m2 = mean_squared_error(y,result)
print(f"MEan 2 Score: {m2:.2f}")

# Visualize Predictions vs Actual Prices
plt.figure(figsize=(8,6))
sns.scatterplot(x=y, y=result)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Car Prices")
plt.show()
# Out:
# Predicted Price: $4225659.85
# R² Score: 0.85
# MEan 2 Score: 9301244.82

# %%
# This is train test split model in model selection 

from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

# lm = LinearRegression()

x_data = df[["km_liter","engine-size","horsepower","curb-weight"]].values
y_data = df["price"].astype(float).values

x_tain,x_test,y_train,y_test = train_test_split(x_data,y_data ,test_size=0.3, random_state= 42)

# This is pipeline for all this model
Input = [('scaler',StandardScaler()), ('polynomial',PolynomialFeatures(degree=2)), ('model', LinearRegression())]
pipe = Pipeline(Input)

pipe.fit(x_tain, y_train)
result_pre = pipe.predict(x_test)

# print(result_pre)

# Predict Price for a New Car
new_car = np.array([[15, 2000, 15, 25000]])  # Example input: 15 km/l, 2000cc, 150 HP, 2500 kg
predicted_price = pipe.predict(new_car)
print(f"Predicted Price: ${predicted_price[0]:.2f}")

# Evaluate Model Performance in r2 method
r2 = r2_score(y_test, result_pre)
print(f"R² Score: {r2:.2f}")

# Evaluate Model Performance in mean squre method
m2 = mean_squared_error(y_test, result_pre)
print(f"MEan 2 Score: {m2:.2f}")

# Visualize Predictions vs Actual Prices
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=result_pre, color="blue", alpha=0.6, edgecolor="black")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', linewidth=2)  # Identity line
plt.xlabel("Actual Price ($)")
plt.ylabel("Predicted Price ($)")
plt.title("Actual vs Predicted Car Prices (Polynomial Regression)")
plt.show()

print("Actual vs Predicted Prices:")
for actual, predicted in zip(y_data[:10], result_pre[:10]):  # Print first 10 predictions
    print(f"Actual: ${actual:.2f}  -->  Predicted: ${predicted:.2f}")
# Out:
# Predicted Price: $3647522.85
# R² Score: 0.78
# MEan 2 Score: 18600263.38
# Actual vs Predicted Prices:
# Actual: $16500.00  -->  Predicted: $22126.52
# Actual: $16500.00  -->  Predicted: $6202.45
# Actual: $13950.00  -->  Predicted: $2516.47
# Actual: $17450.00  -->  Predicted: $9668.60
# Actual: $15250.00  -->  Predicted: $7429.31
# Actual: $17710.00  -->  Predicted: $12391.62
# Actual: $18920.00  -->  Predicted: $10031.78
# Actual: $23875.00  -->  Predicted: $4839.45
# Actual: $16430.00  -->  Predicted: $6481.61
# Actual: $16925.00  -->  Predicted: $9536.97

# %%
# This is for cross_val_score()

from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score


filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lr = LinearRegression()

x_data = df[["km_liter","engine-size","horsepower","curb-weight"]].values
y_data = df["price"].astype(float).values

score = cross_val_score(lr, x_data, y_data, cv =3)

print(score)
# Out:
# [0.80219452 0.74902731 0.54940342]

# %%
# This is for cross_val_score()

from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict


filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lr = LinearRegression()

x_data = df[["km_liter","engine-size","horsepower","curb-weight"]].values
y_data = df["price"].astype(float).values

result_pre = cross_val_predict(lm, x_data, y_data , cv =5)


# print(result[:10])
print("Actual vs Predicted Prices:")
for actual, predicted in zip(y_data[:10], result_pre[:10]):  # Print first 10 predictions
    print(f"Actual: ${actual:.2f}  -->  Predicted: ${predicted:.2f}")

help(zip)
# Out:
# Actual vs Predicted Prices:
# Actual: $16500.00  -->  Predicted: $13559.33
# Actual: $16500.00  -->  Predicted: $17969.24
# Actual: $13950.00  -->  Predicted: $10337.79
# Actual: $17450.00  -->  Predicted: $16112.79
# Actual: $15250.00  -->  Predicted: $14159.96
# Actual: $17710.00  -->  Predicted: $15483.00
# Actual: $18920.00  -->  Predicted: $15914.85
# Actual: $23875.00  -->  Predicted: $17983.06
# Actual: $16430.00  -->  Predicted: $10566.74
# Actual: $16925.00  -->  Predicted: $10566.74
# Help on class zip in module builtins:
#
# class zip(object)
#  |  zip(*iterables, strict=False)
#  |
#  |  The zip object yields n-length tuples, where n is the number of iterables
#  |  passed as positional arguments to zip().  The i-th element in every tuple
#  |  comes from the i-th iterable argument to zip().  This continues until the
#  |  shortest argument is exhausted.
#  |
#  |  If strict is true and one of the arguments is exhausted before the others,
#  |  raise a ValueError.
#  |
# ...

# %%
#  This is for which is best polynomial model 

from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lr = LinearRegression()

x_data = df[["km_liter","engine-size","horsepower","curb-weight"]].values
y_data = df["price"].astype(float).values

x_train,x_test,y_train,y_test = train_test_split(x_data,y_data ,test_size=0.3, random_state= 42)

# This is pipeline for all this model
Input = [('scaler',StandardScaler()), ('polynomial',PolynomialFeatures(degree=2)), ('model', LinearRegression())]
pipe = Pipeline(Input)

pipe.fit(x_train, y_train)
result_pre = pipe.predict(x_test)

rsqu_test = []
order = [1,2,3,4]
x_train = pd.DataFrame(x_train, columns=["km_liter", "engine-size", "horsepower", "curb-weight"])
x_test = pd.DataFrame(x_test, columns=["km_liter", "engine-size", "horsepower", "curb-weight"])
for n in order:
    pr = PolynomialFeatures(degree=n)
    x_train_pr = pr.fit_transform(x_train[["km_liter","engine-size","horsepower","curb-weight"]].values)
    x_test_pr = pr.fit_transform(x_test[["km_liter","engine-size","horsepower","curb-weight"]].values)

    lr.fit(x_train_pr,y_train)

    rsqu_test.append(lr.score(x_test_pr,y_test))
print(rsqu_test)
# Out:
# [0.8255587869143753, 0.7813999716372007, -10.307975431663802, -136.60988731321433]

# %%
# This is  for ridge regression 

from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lr = LinearRegression()

x_data = df[["km_liter","engine-size","horsepower","curb-weight"]].values
y_data = df["price"].astype(float).values

x_train,x_test,y_train,y_test = train_test_split(x_data,y_data ,test_size=0.3, random_state= 42)

ridge = Ridge(alpha= 1.0)
ridge.fit(x_train, y_train)

result_pre = ridge.predict(x_test)
print(result_pre)

r2 = r2_score(y_test, result_pre)
mse = mean_squared_error(y_test, result_pre)

print(f"Ridge Regression Results:")
print(f"🔹 R² Score: {r2:.4f}")
print(f"🔹 Mean Squared Error: {mse:.2f}")

# Predict Price for a New Car
new_car = np.array([[15, 2000, 15, 25000]])  # Example input: 15 km/l, 2000cc, 150 HP, 2500 kg
predicted_price = ridge.predict(new_car)
print(f"Predicted Price: ${predicted_price[0]:.2f}")

# best_r2 = []
# for n in np.arange(1,20,0.5):
#     ridge = Ridge(alpha= n)
#     ridge.fit(x_train, y_train)
#     result_pre = ridge.predict(x_test)
#     r2 = r2_score(y_test, result_pre)
#     best_r2.append({n:r2})
    
# # print(best_r2)
# # closest_value = best_r2[0]
# # min_diff = abs(1 - best_r2[0])

# # for value in best_r2:
# #     diff = abs(1 - value)  # Find the absolute difference from 1
# #     if diff < min_diff:
# #         closest_value = value
# #         min_diff = diff

# print(closest_value)
# Out:
# [22351.24545532  5593.76782638   328.35161502 10398.45595729
#   7700.48237895 13578.55794883 10684.93956862  3988.62677165
#   5504.13716073  9830.24615511 10300.99904938 28411.32215243
#  11238.92328154 11303.64697733  9393.8298692  44543.39442158
#  24938.75797826 11100.39757073  7385.17301169  6535.47452674
#  17946.15753148 15367.16386401 11342.48119481 16115.15118422
#   6091.98634698 30774.64356019 12058.68635572 15737.38340395
#   6027.15016611  6127.24315794 40111.03646389 11673.29952471
#  13482.76687905 11452.10546117  6027.15016611 18661.37664404
#  11129.01136199 21668.8932905   5485.03201745  7236.06327212
#  11022.92407799 15879.81735979 23063.20610906 11801.63462887
#  16382.35497605 11750.72291925 23531.83474123 14718.60730901
#  19408.6878816   9723.1033589   8189.31530336 12531.55560555
#  30917.03569094 16218.70909749  9437.84198234 11185.96821429
#  19293.0196089   6091.174314   10391.6122235  15405.99808148]
# Ridge Regression Results:
# 🔹 R² Score: 0.8256
# ...

# %%
# THis is for grid search

from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(filepath , na_values = '?') 
df.head(20)
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns= headers

# This is to drop NA value in dataset
df.dropna(subset=["highway-mpg","price","engine-size","horsepower","curb-weight"], inplace=True)
# This is to convert m/g to km/l 
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns= {"highway-mpg" : "km_liter"},inplace=True)

lr = LinearRegression()

x_data = df[["km_liter","engine-size","horsepower","curb-weight"]].values
y_data = df["price"].astype(float).values

x_train,x_test,y_train,y_test = train_test_split(x_data,y_data ,test_size=0.3, random_state= 42)

rr = Ridge()

parameter  = [{'alpha:[0.001,0.1,1,10,100,1000,10000,100000]'}]
# x_data = pd.DataFrame(x_data, columns=["km_liter", "engine-size", "horsepower", "curb-weight"])

Grid1 = GridSearchCV(rr,parameter, cv = 4)
Grid1.fit(x_data[["km_liter", "engine-size", "horsepower", "curb-weight"]].values, y_data)
Grid1.best_estimator_

score = Grid1.cv_results_
score['mean_test_score']
# ridge = Ridge(alpha= 1.0)
# ridge.fit(x_train, y_train)

# result_pre = ridge.predict(x_test)
# print(result_pre)

# r2 = r2_score(y_test, result_pre)
# mse = mean_squared_error(y_test, result_pre)

# print(f"Ridge Regression Results:")
# print(f"🔹 R² Score: {r2:.4f}")
# print(f"🔹 Mean Squared Error: {mse:.2f}")

# # Predict Price for a New Car
# new_car = np.array([[15, 2000, 15, 25000]])  # Example input: 15 km/l, 2000cc, 150 HP, 2500 kg
# predicted_price = ridge.predict(new_car)
# print(f"Predicted Price: ${predicted_price[0]:.2f}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[342], line 47
#      44 # x_data = pd.DataFrame(x_data, columns=["km_liter", "engine-size", "horsepower", "curb-weight"])
#      46 Grid1 = GridSearchCV(rr,parameter, cv = 4)
# ---> 47 Grid1.fit(x_data[["km_liter", "engine-size", "horsepower", "curb-weight"]].values, y_data)
#      48 Grid1.best_estimator_
#      50 score = Grid1.cv_results_
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
